# %%
import tushare as ts
from dotenv import load_dotenv
import os
load_dotenv()
api_key = os.environ.get("API_KEY")
ts.set_token(api_key)
pro = ts.pro_api()
df = ts.pro_bar(ts_code='873001.bj', start_date='20200806', end_date='20250806', adj='cq')
# Out:
# C:\Users\31021\anaconda3\envs\tushare_3.11\Lib\site-packages\tushare\pro\data_pro.py:130: FutureWarning: Series.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   data['adj_factor'] = data['adj_factor'].fillna(method='bfill')

# %%
pro.index_member_all(ts_code='000001.SZ')['name'][0]
# Out:
# '平安银行'

# %%
pro.index_weight(index_code='399300.SZ', start_date='20180901', end_date='20180930')
# Out:
#     index_code   con_code trade_date  weight
# 0    399300.SZ  601318.SH   20180928  7.0920
# 1    399300.SZ  600519.SH   20180928  3.5060
# 2    399300.SZ  600036.SH   20180928  3.0260
# 3    399300.SZ  601166.SH   20180928  1.9000
# 4    399300.SZ  000651.SZ   20180928  1.8490
# ..         ...        ...        ...     ...
# 595  399300.SZ  601108.SH   20180903  0.0385
# 596  399300.SZ  002608.SZ   20180903  0.0361
# 597  399300.SZ  601838.SH   20180903  0.0345
# 598  399300.SZ  601212.SH   20180903  0.0325
# 599  399300.SZ  601878.SH   20180903  0.0241
#
# [600 rows x 4 columns]

# %%
pro.index_basic(fields="ts_code,name,fullname,market,publisher,index_type,category,base_date,base_point,list_date,"
                                           "weight_rule,desc,exp_date")
# Out:
#                ts_code              name                fullname market  \
# 0            000001.CJ            能源(长江)                长江证券能源指数    OTH
# 1            000001.SH              上证指数                  上证综合指数    SSE
# 2            000002.CJ           原材料(长江)               长江证券原材料指数    OTH
# 3            000002.SH              上证A指                  上证A股指数    SSE
# 4            000003.CJ            工业(长江)                长江证券工业指数    OTH
# ...                ...               ...                     ...    ...
# 7995  932272CNY210.CSI      港股通计算机(全)CNY      中证港股通计算机综合人民币全收益指数    CSI
# 7996  932272HKD210.CSI         港股通计算机(全)         中证港股通计算机综合全收益指数    CSI
# 7997        932273.CSI           港股通医疗器械           中证港股通医疗器械综合指数    CSI
# 7998  932273CNY100.CSI     港股通医疗器械人民币中间价     中证港股通医疗器械综合人民币中间价指数    CSI
# 7999  932273CNY110.CSI  港股通医疗器械人民币中间价(全)  中证港股通医疗器械综合人民币中间价全收益指数    CSI
#
#        publisher index_type category base_date  base_point list_date  \
# ...

# %%
idf = pro.index_weight(index_code="000300.SH",start_date='20041231', end_date='20250808')

# %%
idf
# Out:
#      index_code   con_code trade_date  weight
# 0     000300.SH  600519.SH   20250801  4.1366
# 1     000300.SH  300750.SZ   20250801  3.2304
# 2     000300.SH  601318.SH   20250801  2.9113
# 3     000300.SH  600036.SH   20250801  2.5554
# 4     000300.SH  601166.SH   20250801  1.7403
# ...         ...        ...        ...     ...
# 5995  000300.SH  601808.SH   20241031  0.0450
# 5996  000300.SH  300957.SZ   20241031  0.0440
# 5997  000300.SH  000800.SZ   20241031  0.0420
# 5998  000300.SH  603296.SH   20241031  0.0260
# 5999  000300.SH  001289.SZ   20241031  0.0140
#
# [6000 rows x 4 columns]

# %%
idf['trade_date'].unique()
# Out:
# array([], dtype=object)

# %%
cq = ts.pro_bar(ts_code='000300.SH', asset='I',start_date='20230101', end_date='20250701', adj='cq')
qfq = ts.pro_bar(ts_code='000300.SH', asset='I',start_date='20230101', end_date='20250701', adj='qfq')
hfq = ts.pro_bar(ts_code='000300.SH', asset='I',start_date='20230101', end_date='20250701', adj='hfq')
cq
# Out:
#        ts_code trade_date      close       open       high        low  \
# 0    000300.SH   20250701  3942.7620  3935.9078  3946.2451  3924.7219
# 1    000300.SH   20250630  3936.0791  3920.3149  3940.3611  3911.6044
# 2    000300.SH   20250627  3921.7578  3949.7879  3969.2626  3918.2041
# 3    000300.SH   20250626  3946.0195  3953.1603  3964.4820  3945.2589
# 4    000300.SH   20250625  3960.0662  3907.0682  3963.0371  3902.1771
# ..         ...        ...        ...        ...        ...        ...
# 597  000300.SH   20230109  4013.1196  3998.5278  4023.0898  3990.7073
# 598  000300.SH   20230106  3980.8888  3969.5493  4000.4143  3966.4696
# 599  000300.SH   20230105  3968.5782  3913.4928  3974.8750  3912.2600
# 600  000300.SH   20230104  3892.9477  3886.2504  3905.9032  3873.6549
# 601  000300.SH   20230103  3887.8992  3864.8356  3893.9904  3831.2450
#
#      pre_close   change  pct_chg          vol        amount
# 0    3936.0791   6.6829   0.1698  128959362.0  2.360703e+08
# ...

# %%
qfq
# Out:
#        ts_code trade_date      close       open       high        low  \
# 0    000300.SH   20250701  3942.7620  3935.9078  3946.2451  3924.7219
# 1    000300.SH   20250630  3936.0791  3920.3149  3940.3611  3911.6044
# 2    000300.SH   20250627  3921.7578  3949.7879  3969.2626  3918.2041
# 3    000300.SH   20250626  3946.0195  3953.1603  3964.4820  3945.2589
# 4    000300.SH   20250625  3960.0662  3907.0682  3963.0371  3902.1771
# ..         ...        ...        ...        ...        ...        ...
# 597  000300.SH   20230109  4013.1196  3998.5278  4023.0898  3990.7073
# 598  000300.SH   20230106  3980.8888  3969.5493  4000.4143  3966.4696
# 599  000300.SH   20230105  3968.5782  3913.4928  3974.8750  3912.2600
# 600  000300.SH   20230104  3892.9477  3886.2504  3905.9032  3873.6549
# 601  000300.SH   20230103  3887.8992  3864.8356  3893.9904  3831.2450
#
#      pre_close   change  pct_chg          vol        amount
# 0    3936.0791   6.6829   0.1698  128959362.0  2.360703e+08
# ...

# %%
hfq
# Out:
#        ts_code trade_date      close       open       high        low  \
# 0    000300.SH   20250701  3942.7620  3935.9078  3946.2451  3924.7219
# 1    000300.SH   20250630  3936.0791  3920.3149  3940.3611  3911.6044
# 2    000300.SH   20250627  3921.7578  3949.7879  3969.2626  3918.2041
# 3    000300.SH   20250626  3946.0195  3953.1603  3964.4820  3945.2589
# 4    000300.SH   20250625  3960.0662  3907.0682  3963.0371  3902.1771
# ..         ...        ...        ...        ...        ...        ...
# 597  000300.SH   20230109  4013.1196  3998.5278  4023.0898  3990.7073
# 598  000300.SH   20230106  3980.8888  3969.5493  4000.4143  3966.4696
# 599  000300.SH   20230105  3968.5782  3913.4928  3974.8750  3912.2600
# 600  000300.SH   20230104  3892.9477  3886.2504  3905.9032  3873.6549
# 601  000300.SH   20230103  3887.8992  3864.8356  3893.9904  3831.2450
#
#      pre_close   change  pct_chg          vol        amount
# 0    3936.0791   6.6829   0.1698  128959362.0  2.360703e+08
# ...

# %%
qfq[qfq.ne(hfq).any(axis=1)]
# Out:
# Empty DataFrame
# Columns: [ts_code, trade_date, close, open, high, low, pre_close, change, pct_chg, vol, amount]
# Index: []

# %%
pro.adj_factor(ts_code='000005.SZ', trade_date='')
# Out:
#         ts_code trade_date  adj_factor
# 0     000005.SZ   20240425       9.268
# 1     000005.SZ   20240424       9.268
# 2     000005.SZ   20240423       9.268
# 3     000005.SZ   20240422       9.268
# 4     000005.SZ   20240419       9.268
# ...         ...        ...         ...
# 5995  000005.SZ   19990729       4.433
# 5996  000005.SZ   19990728       4.433
# 5997  000005.SZ   19990727       4.433
# 5998  000005.SZ   19990726       4.433
# 5999  000005.SZ   19990723       4.433
#
# [6000 rows x 3 columns]

# %%
ts.pro_bar(ts_code='000001.SZ',adjfactor=True)
# Out:
#         ts_code trade_date   open   high    low  close  pre_close  change  \
# 0     000001.SZ   20250808  12.48  12.53  12.39  12.40      12.47   -0.07
# 1     000001.SZ   20250807  12.44  12.53  12.39  12.47      12.46    0.01
# 2     000001.SZ   20250806  12.47  12.52  12.40  12.46      12.47   -0.01
# 3     000001.SZ   20250805  12.30  12.50  12.28  12.47      12.30    0.17
# 4     000001.SZ   20250804  12.24  12.38  12.21  12.30      12.28    0.02
# ...         ...        ...    ...    ...    ...    ...        ...     ...
# 5995  000001.SZ   20000323  18.50  18.72  18.26  18.61      18.48    0.13
# 5996  000001.SZ   20000322  18.26  18.65  18.15  18.48      18.26    0.22
# 5997  000001.SZ   20000321  18.22  18.39  18.00  18.26      18.22    0.04
# 5998  000001.SZ   20000320  17.90  18.37  17.68  18.22      18.17    0.05
# 5999  000001.SZ   20000317  17.80  18.32  17.78  18.17        NaN     NaN
#
#       pct_chg         vol        amount
# ...

# %%
from utils.utils import *
pro = easyPro()

# %%
ts.pro_bar(ts_code='801770.SI')
# Out:
# Empty DataFrame
# Columns: [ts_code, trade_date, open, high, low, close, pre_close, change, pct_chg, vol, amount]
# Index: []

# %%
pro.sw_daily(ts_code='801080.SI')
# Out:
#         ts_code trade_date name     open      low     high    close  change  \
# 0     801080.SI   20250811   电子  4951.52  4951.51  5049.13  5035.26   87.03
# 1     801080.SI   20250808   电子  4980.92  4946.59  4980.92  4948.23  -57.79
# 2     801080.SI   20250807   电子  5005.89  4973.24  5037.81  5006.02   22.27
# 3     801080.SI   20250806   电子  4925.69  4917.96  4984.28  4983.75   45.25
# 4     801080.SI   20250805   电子  4927.86  4906.31  4940.11  4938.50   28.33
# ...         ...        ...  ...      ...      ...      ...      ...     ...
# 3160  801080.SI   20120807   电子  1223.83  1222.57  1234.78  1233.85    9.57
# 3161  801080.SI   20120806   电子  1191.14  1188.81  1225.06  1224.28   29.51
# 3162  801080.SI   20120803   电子  1161.96  1160.99  1194.77  1194.77   35.09
# 3163  801080.SI   20120802   电子  1154.72  1153.28  1166.99  1159.68    2.83
# 3164  801080.SI   20120801   电子  1133.04  1132.40  1163.11  1156.86   21.65
#
# ...

# %%
code='000001.SZ'
start_date='20200806'
end_date='20250806'
df = pro.daily_basic(ts_code=code, start_date=start_date, end_date=end_date,
                     fields=['ts_code', 'trade_date', 'total_mv', 'pe_ttm', 'pb', 'ps_ttm', 'dv_ttm'])

# %%
df
# Out:
#         ts_code trade_date      total_mv  pe_ttm      pb  ps_ttm  dv_ttm
# 0     000001.SZ   20250806  2.417977e+07  5.5367  0.5635  1.7072  4.8796
# 1     000001.SZ   20250805  2.419918e+07  5.5411  0.5639  1.7086  4.8757
# 2     000001.SZ   20250804  2.386928e+07  5.4656  0.5562  1.6853  4.9431
# 3     000001.SZ   20250801  2.383047e+07  5.4567  0.5553  1.6825  4.9512
# 4     000001.SZ   20250731  2.373344e+07  5.4345  0.5531  1.6757  4.9714
# ...         ...        ...           ...     ...     ...     ...     ...
# 1208  000001.SZ   20200812  2.790571e+07  9.5251  1.0032  1.9459  1.5160
# 1209  000001.SZ   20200811  2.742056e+07  9.3595  0.9857  1.9121  1.5428
# 1210  000001.SZ   20200810  2.707126e+07  9.2403  0.9732  1.8877  1.5627
# 1211  000001.SZ   20200807  2.658611e+07  9.0747  0.9557  1.8539  1.5912
# 1212  000001.SZ   20200806  2.697423e+07  9.2072  0.9697  1.8809  1.5683
#
# [1213 rows x 7 columns]

# %%
pro.fina_indicator(ts_code=code, start_date=start_date,
                                    fields='ts_code,end_date,ebitda')
# Out:
#       ts_code  end_date ebitda
# 0   000001.SZ  20250331   None
# 1   000001.SZ  20250331   None
# 2   000001.SZ  20241231   None
# 3   000001.SZ  20240930   None
# 4   000001.SZ  20240630   None
# 5   000001.SZ  20240630   None
# 6   000001.SZ  20240331   None
# 7   000001.SZ  20231231   None
# 8   000001.SZ  20230930   None
# 9   000001.SZ  20230630   None
# 10  000001.SZ  20230331   None
# 11  000001.SZ  20230331   None
# 12  000001.SZ  20221231   None
# 13  000001.SZ  20221231   None
# 14  000001.SZ  20220930   None
# 15  000001.SZ  20220930   None
# 16  000001.SZ  20220630   None
# 17  000001.SZ  20220630   None
# 18  000001.SZ  20220331   None
# 19  000001.SZ  20220331   None
# 20  000001.SZ  20211231   None
# 21  000001.SZ  20211231   None
# 22  000001.SZ  20210930   None
# 23  000001.SZ  20210630   None
# 24  000001.SZ  20210630   None
# 25  000001.SZ  20210331   None
# 26  000001.SZ  20201231   None
# 27  000001.SZ  20201231   None
# 28  000001.SZ  20200930   None

# %%
pro.stk_holdernumber(ts_code='300199.SZ', start_date='20160101', end_date='20181231')
# Out:
#       ts_code  ann_date  end_date  holder_num
# 0   300199.SZ  20181025  20180930       25135
# 1   300199.SZ  20180808  20180630       25785
# 2   300199.SZ  20180426  20180331       23384
# 3   300199.SZ  20180316  20180228       23490
# 4   300199.SZ  20180316  20171231       24086
# 5   300199.SZ  20171026  20170930       24121
# 6   300199.SZ  20170817  20170630       26271
# 7   300199.SZ  20170427  20170331       24531
# 8   300199.SZ  20170427  20161231       22972
# 9   300199.SZ  20161028  20161027       19787
# 10  300199.SZ  20161027  20160930       19787
# 11  300199.SZ  20160804  20160630       20050
# 12  300199.SZ  20160428  20160331       23367
# 13  300199.SZ  20160428  20151231       21407

# %%
pro.margin_detail(ts_code='300199.SZ', start_date='20160101', end_date='20181231')
# Out:
#     trade_date    ts_code         rzye      rqye       rzmre     rqyl  \
# 0     20181228  300199.SZ  487329045.0  518417.0  18452815.0  55505.0
# 1     20181227  300199.SZ  488797791.0  613965.0  16605654.0  61705.0
# 2     20181226  300199.SZ  479572534.0  636103.0  11734294.0  61105.0
# 3     20181225  300199.SZ  481880351.0  530111.0   9814185.0  50105.0
# 4     20181224  300199.SZ  492763775.0  517585.0   6634765.0  50105.0
# ..         ...        ...          ...       ...         ...      ...
# 726   20160108  300199.SZ  843228565.0       0.0  57300813.0      0.0
# 727   20160107  300199.SZ  862130146.0       0.0   8057117.0      0.0
# 728   20160106  300199.SZ  893930283.0       0.0  32897672.0      0.0
# 729   20160105  300199.SZ  894453515.0       0.0  45935348.0      0.0
# 730   20160104  300199.SZ  961313443.0       0.0  50895377.0      0.0
#
#            rzche    rqchl    rqmcl       rzrqye
# 0     19921561.0  14700.0   8500.0  487847462.0
# ...

# %%
import pandas as pd
start_date = pd.to_datetime('20200801')
end_date = pd.to_datetime('20200815')
lister = []
for date in pd.date_range(start=start_date, end=end_date):
    lister.append(pro.top_inst(ts_code='600580.SZ',trade_date=date.strftime("%Y%m%d")))
pd.concat(lister, ignore_index=True)
# Out:
# Empty DataFrame
# Columns: [trade_date, ts_code, exalter, buy, buy_rate, sell, sell_rate, net_buy, side, reason]
# Index: []

# %%
pro.report_rc(ts_code='301299.SZ',start_date='20200601', end_date='20250801')
# Out:
#      ts_code  name report_date                report_title report_type  \
# 0  301299.SZ  卓创资讯    20230330     计算机行业深度报告：数据要素市场化建设有望提速         非个股
# 1  301299.SZ  卓创资讯    20221222  卓创资讯：产业数据商受益于经济上行和数据要素政策红利          点评
# 2  301299.SZ  卓创资讯    20221222  卓创资讯：产业数据商受益于经济上行和数据要素政策红利          点评
# 3  301299.SZ  卓创资讯    20221222  卓创资讯：产业数据商受益于经济上行和数据要素政策红利          点评
#
#   classify org_name  author_name quarter    op_rt  ...       tp       np  \
# 0     一般报告     东莞证券  罗炜斌,刘梦麟,陈伟光  2023Q4      NaN  ...      NaN   9900.0
# 1     首份报告     国联证券   孙树明,黄楷,姜青山  2022Q4  28100.0  ...   7400.0   6400.0
# 2     首份报告     国联证券   孙树明,黄楷,姜青山  2023Q4  39300.0  ...  11400.0   9900.0
# 3     首份报告     国联证券   孙树明,黄楷,姜青山  2024Q4  51100.0  ...  15900.0  13800.0
#
#     eps     pe    rd    roe  ev_ebitda  rating max_price min_price
# 0  1.65    NaN  None    NaN        NaN      买入      None       NaN
# 1  1.07  51.19  None   8.50      22.34      买入      None      96.0
# ...

# %%
ts.pro_bar(ts_code='000627.SZ')
# Out:
#         ts_code trade_date   open   high    low  close  pre_close  change  \
# 0     000627.SZ   20250812   1.56   1.57   1.56   1.56       1.52    0.04
# 1     000627.SZ   20250811   1.52   1.52   1.52   1.52       1.45    0.07
# 2     000627.SZ   20250806   1.39   1.47   1.36   1.45       1.42    0.03
# 3     000627.SZ   20250805   1.37   1.45   1.35   1.42       1.39    0.03
# 4     000627.SZ   20250804   1.44   1.45   1.39   1.39       1.46   -0.07
# ...         ...        ...    ...    ...    ...    ...        ...     ...
# 5995  000627.SZ   19991112  15.98  16.09  15.86  15.99      15.98    0.01
# 5996  000627.SZ   19991111  15.87  16.19  15.86  15.98      15.88    0.10
# 5997  000627.SZ   19991110  15.88  15.98  15.80  15.88      15.91   -0.03
# 5998  000627.SZ   19991109  15.89  15.98  15.70  15.91      15.89    0.02
# 5999  000627.SZ   19991108  15.98  16.18  15.70  15.89        NaN     NaN
#
#       pct_chg         vol       amount
# 0        2.63  4481760.01  700386.3020
# ...

# %%
testday = pd.to_datetime('20200601')
testday
# Out:
# Timestamp('2020-06-01 00:00:00')

# %%
testday.YearBegin()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[24], line 1
# ----> 1 testday.YearBegin()
#
# AttributeError: 'Timestamp' object has no attribute 'YearBegin'

# %%
def get_quarter_dates(year):
    # 创建四个季度period
    quarters = [pd.Period(f'{year}-Q{q}') for q in range(1, 5)]

    # 获取每个季度的第一天和最后一天
    starts = [q.start_time for q in quarters]
    ends = [q.end_time for q in quarters]

    return starts, ends

# 示例
starts, ends = get_quarter_dates(pd.to_datetime('20200601').year)
print("季度第一天:", starts)
print("季度最后一天:", ends)
# Out:
# 季度第一天: [Timestamp('2020-01-01 00:00:00'), Timestamp('2020-04-01 00:00:00'), Timestamp('2020-07-01 00:00:00'), Timestamp('2020-10-01 00:00:00')]
# 季度最后一天: [Timestamp('2020-03-31 23:59:59.999999999'), Timestamp('2020-06-30 23:59:59.999999999'), Timestamp('2020-09-30 23:59:59.999999999'), Timestamp('2020-12-31 23:59:59.999999999')]

# %%
start_date = pd.to_datetime('20200601')
end_date = pd.to_datetime('20250301')
for year in range(start_date.year, end_date.year):
    print(year)
    print(type(year))
# Out:
# 2020
# <class 'int'>
# 2021
# <class 'int'>
# 2022
# <class 'int'>
# 2023
# <class 'int'>
# 2024
# <class 'int'>

# %%
quarter_starts, quarter_ends = [], []
for year in range(start_date.year, end_date.year + 1):
    tempstart, tempend = get_quarter_dates(year)
    quarter_starts.extend(tempstart)
    quarter_ends.extend(tempend)

# %%
quarter_ends
# Out:
# [Timestamp('2020-03-31 23:59:59.999999999'),
#  Timestamp('2020-06-30 23:59:59.999999999'),
#  Timestamp('2020-09-30 23:59:59.999999999'),
#  Timestamp('2020-12-31 23:59:59.999999999'),
#  Timestamp('2021-03-31 23:59:59.999999999'),
#  Timestamp('2021-06-30 23:59:59.999999999'),
#  Timestamp('2021-09-30 23:59:59.999999999'),
#  Timestamp('2021-12-31 23:59:59.999999999'),
#  Timestamp('2022-03-31 23:59:59.999999999'),
#  Timestamp('2022-06-30 23:59:59.999999999'),
#  Timestamp('2022-09-30 23:59:59.999999999'),
#  Timestamp('2022-12-31 23:59:59.999999999'),
#  Timestamp('2023-03-31 23:59:59.999999999'),
#  Timestamp('2023-06-30 23:59:59.999999999'),
#  Timestamp('2023-09-30 23:59:59.999999999'),
#  Timestamp('2023-12-31 23:59:59.999999999'),
#  Timestamp('2024-03-31 23:59:59.999999999'),
#  Timestamp('2024-06-30 23:59:59.999999999'),
#  Timestamp('2024-09-30 23:59:59.999999999'),
#  Timestamp('2024-12-31 23:59:59.999999999'),
#  Timestamp('2025-03-31 23:59:59.999999999'),
# ...

# %%
for start, end in zip(quarter_starts, quarter_ends):
    print(start, end)
# Out:
# 2020-01-01 00:00:00 2020-03-31 23:59:59.999999999
# 2020-04-01 00:00:00 2020-06-30 23:59:59.999999999
# 2020-07-01 00:00:00 2020-09-30 23:59:59.999999999
# 2020-10-01 00:00:00 2020-12-31 23:59:59.999999999
# 2021-01-01 00:00:00 2021-03-31 23:59:59.999999999
# 2021-04-01 00:00:00 2021-06-30 23:59:59.999999999
# 2021-07-01 00:00:00 2021-09-30 23:59:59.999999999
# 2021-10-01 00:00:00 2021-12-31 23:59:59.999999999
# 2022-01-01 00:00:00 2022-03-31 23:59:59.999999999
# 2022-04-01 00:00:00 2022-06-30 23:59:59.999999999
# 2022-07-01 00:00:00 2022-09-30 23:59:59.999999999
# 2022-10-01 00:00:00 2022-12-31 23:59:59.999999999
# 2023-01-01 00:00:00 2023-03-31 23:59:59.999999999
# 2023-04-01 00:00:00 2023-06-30 23:59:59.999999999
# 2023-07-01 00:00:00 2023-09-30 23:59:59.999999999
# 2023-10-01 00:00:00 2023-12-31 23:59:59.999999999
# 2024-01-01 00:00:00 2024-03-31 23:59:59.999999999
# 2024-04-01 00:00:00 2024-06-30 23:59:59.999999999
# 2024-07-01 00:00:00 2024-09-30 23:59:59.999999999
# ...

# %%
income = pro.income(ts_code="000001.SZ",
           fields="ts_code,ann_date,end_date,revenue,total_revenue,n_income,oper_cost"
           )

# %%
income
# Out:
#        ts_code  ann_date  end_date       revenue  total_revenue      n_income  \
# 0    000001.SZ  20250419  20250331  3.370900e+10   3.370900e+10  1.409600e+10
# 1    000001.SZ  20250315  20241231  1.466950e+11   1.466950e+11  4.450800e+10
# 2    000001.SZ  20241019  20240930  1.115820e+11   1.115820e+11  3.972900e+10
# 3    000001.SZ  20240816  20240630  7.713200e+10   7.713200e+10  2.587900e+10
# 4    000001.SZ  20240420  20240331  3.877000e+10   3.877000e+10  1.493200e+10
# ..         ...       ...       ...           ...            ...           ...
# 118  000001.SZ  19970421  19961231  1.560670e+09   1.560670e+09  7.873006e+08
# 119  000001.SZ  19960829  19960630  1.144943e+09   1.144943e+09  3.641234e+08
# 120  000001.SZ  19960209  19951231  9.802463e+08   9.802463e+08  4.350597e+08
# 121  000001.SZ  19950811  19950630  8.424990e+08   8.424990e+08  2.165011e+08
# 122  000001.SZ  19950310  19941231  7.404704e+08   7.404704e+08  3.563280e+08
#
#      oper_cost
# 0          NaN
# ...

# %%
income['gross_profit'] = income['revenue'] - income['oper_cost']
income
# Out:
#        ts_code  end_date       revenue  total_revenue      n_income  \
# 0    000001.SZ  20250331  3.370900e+10   3.370900e+10  1.409600e+10
# 1    000001.SZ  20241231  1.466950e+11   1.466950e+11  4.450800e+10
# 2    000001.SZ  20240930  1.115820e+11   1.115820e+11  3.972900e+10
# 3    000001.SZ  20240630  7.713200e+10   7.713200e+10  2.587900e+10
# 4    000001.SZ  20240331  3.877000e+10   3.877000e+10  1.493200e+10
# ..         ...       ...           ...            ...           ...
# 118  000001.SZ  19961231  1.560670e+09   1.560670e+09  7.873006e+08
# 119  000001.SZ  19960630  1.144943e+09   1.144943e+09  3.641234e+08
# 120  000001.SZ  19951231  9.802463e+08   9.802463e+08  4.350597e+08
# 121  000001.SZ  19950630  8.424990e+08   8.424990e+08  2.165011e+08
# 122  000001.SZ  19941231  7.404704e+08   7.404704e+08  3.563280e+08
#
#      oper_cost  gross_profit
# 0          0.0  3.370900e+10
# 1          0.0  1.466950e+11
# 2          0.0  1.115820e+11
# 3          0.0  7.713200e+10
# ...
